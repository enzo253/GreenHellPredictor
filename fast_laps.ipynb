# %%
from dotenv import load_dotenv
import requests
import os
from bs4 import BeautifulSoup
import psycopg2
from datetime import timedelta
import pandas as pd
from together import Together

# %%
load_dotenv()

railway_key = os.getenv("MY_CAR_KEY")

print(railway_key)
# Out:
# postgresql://postgres:GKJvbauIQhfsuLaQErahmqRtMFwBkCpZ@shuttle.proxy.rlwy.net:38563/railway

# %%
def get_data():
    url = "https://fastestlaps.com/tracks/nordschleife"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    data = []
    rows = soup.find_all("tr")

    for text in rows:

        columns = text.find_all("td")
        car_info = [col.get_text(strip=True) for col in columns]

        if len(car_info) == 5:
            position = car_info[0]
            car = car_info[1]
            driver = car_info[2]
            lap_time = car_info[3]
            power_weight = car_info[4]

            data.append({"car": car, "driver": driver, "lap_time": lap_time, "power_weight": power_weight})

    return data

# %%
BASE_URL = "https://fastestlaps.com"


def get_car_links():

    url = BASE_URL + "/tracks/nordschleife"
    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")

    rows = soup.find_all("tr")
    data = []

    for row in rows:

        car_column = row.find_all("td")

        for link in car_column:
            references = link.find("a")

            if references and references.has_attr("href"):
                car_name = references.get_text(strip=True)
                car_links = references.get("href")
                full_link = BASE_URL + car_links
                data.append((car_name, full_link))

    return data

# %%
def get_car_specs(car_links):
    data = []

    acceleration_keys = [
        "Top speed", "Car type", "Curb weight", "Est. max acceleration", "0 - 40 kph", "0 - 50 kph", "0 - 60 kph",
        "0 - 80 kph", "0 - 100 kph", "0 - 120 kph",
        "0 - 130 kph", "0 - 140 kph"
    ]

    for src in car_links:
        url = src[1]  
        response = requests.get(url, timeout=10)  
        soup = BeautifulSoup(response.text, "html.parser")

        specs = soup.find_all("table", class_="table fl-datasheet")

        car_info = {}

        for table in specs:
            rows = table.find_all("tr")

            for row in rows:
                cols = row.find_all("td")

                if len(cols) >= 2:
                    key = cols[0].get_text(strip=True)
                    value = cols[1].get_text(strip=True)

                    car_info[key] = value


        acceleration_data = {
            key: car_info.get(key, None)
            for key in acceleration_keys
        }

        if acceleration_data:
            data.append(acceleration_data)

    return data

# %%
def clean_data(fast_laps, car_specs):
    
    fast_laps_df = pd.DataFrame(fast_laps, columns=["car", "driver", "lap_time", "power_weight"])
    car_specs_df = pd.DataFrame(car_specs, columns=[
        "Top speed", "Car type", "Curb weight", "Est. max acceleration", "0 - 40 kph", "0 - 50 kph", "0 - 60 kph",
        "0 - 80 kph", "0 - 100 kph", "0 - 120 kph",
        "0 - 130 kph", "0 - 140 kph"
    ])

    acceleration_cols = [
        "0 - 40 kph", "0 - 50 kph", "0 - 60 kph",
        "0 - 80 kph", "0 - 100 kph", "0 - 120 kph",
        "0 - 130 kph", "0 - 140 kph"
    ]

    car_specs_df[acceleration_cols] = (
        car_specs_df[acceleration_cols]
        .astype(str)
        .replace({"None": None, "nan": None, "": None})
        .apply(lambda col: col.str.replace("s", "", regex=False))
        .apply(pd.to_numeric, errors="coerce")
    )

    fast_laps_df["lap_time"] = fast_laps_df["lap_time"].replace({"None": None, "": None})    
    fast_laps_df["lap_time"] = pd.to_timedelta("00:" + fast_laps_df["lap_time"])

    fast_laps_df["lap_time"] = fast_laps_df["lap_time"].apply(lambda x: str(x))

    fast_laps_df["power_weight"] = fast_laps_df["power_weight"].apply(
        lambda x: (
            float(x.split("/")[0].strip()) / float(x.split("/")[1].strip()) 
            if isinstance(x, str) and "/" in x
            and x.split("/")[0].strip() not in ['-', ''] 
            and x.split("/")[1].strip() not in ['-', ''] 
            and float(x.split("/")[1].strip()) != 0
            else None
        )
    )

    car_specs_df['Top speed'] = car_specs_df["Top speed"].str.extract(r"(\d+)")
    car_specs_df["Est. max acceleration"] = car_specs_df["Est. max acceleration"].str.extract(r"(\d+\.\d+)")
    car_specs_df["Curb weight"] = car_specs_df["Curb weight"].str.extract(r"(\d+)")

    car_specs_df["Est. max acceleration"] = car_specs_df["Est. max acceleration"].astype(float)
    car_specs_df["Top speed"] = car_specs_df["Top speed"].astype(float)
    car_specs_df["Curb weight"] = car_specs_df["Curb weight"].astype(float)


    print(car_specs_df.head())
 
    return fast_laps_df, car_specs_df

# %%
def save_to_database(fast_laps_df, car_specs_df, railway_key):
    try:
        conn = psycopg2.connect(railway_key)
        cursor = conn.cursor()
        engine = create_engine(railway_key)


        cursor.execute("DROP TABLE IF EXISTS car_info CASCADE")
        cursor.execute("DROP TABLE IF EXISTS car_specs CASCADE")

        cursor.execute('''CREATE TABLE IF NOT EXISTS car_info (
            id SERIAL PRIMARY KEY,
            car VARCHAR(255),
            driver VARCHAR(255),
            lap_time TEXT,
            power_weight FLOAT
        )''')

        cursor.execute('''CREATE TABLE IF NOT EXISTS car_specs (
            id SERIAL PRIMARY KEY,
            "Top speed" FLOAT, 
            "Car type" TEXT, 
            "Curb weight" FlOAT, 
            "Est. max acceleration" FLOAT, 
            "0 - 40 kph" FLOAT, 
            "0 - 50 kph" FLOAT, 
            "0 - 60 kph" FLOAT,
            "0 - 80 kph" FLOAT, 
            "0 - 100 kph" FLOAT, 
            "0 - 120 kph" FLOAT,
            "0 - 130 kph" FLOAT, 
            "0 - 140 kph" FLOAT
        )''')


        fast_laps_records = fast_laps_df.to_records(index=False).tolist()
        car_specs_records = car_specs_df.to_records(index=False).tolist()


        if fast_laps_records:
            insert_query = '''INSERT INTO car_info (car, driver, lap_time, power_weight) 
                              VALUES (%s, %s, %s, %s)'''
            cursor.executemany(insert_query, fast_laps_records)
        

        if car_specs_records:
            insert_query = '''INSERT INTO car_specs ("Top speed", "Car type", "Curb weight", 
                                                     "Est. max acceleration", "0 - 40 kph", 
                                                     "0 - 50 kph", "0 - 60 kph", "0 - 80 kph", 
                                                     "0 - 100 kph", "0 - 120 kph", 
                                                     "0 - 130 kph", "0 - 140 kph") 
                              VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
            cursor.executemany(insert_query, car_specs_records)

        conn.commit()
        print("Data saved successfully!")

    except Exception as e:
        print(f"Data did not save. Error: {e}")

    finally:
        conn.close()

# %%
fast_laps = get_data()
print(fast_laps)

car_links = get_car_links()
print("Car Links:", car_links) 

car_specs = get_car_specs(car_links)
print("Car Specs:", car_specs)
# Out:
# [{'car': 'Mercedes - AMG One', 'driver': 'Maro Engel', 'lap_time': '6:30.70', 'power_weight': '1063 / 1695'}, {'car': 'Porsche 911 GT2 RS Manthey Racing', 'driver': 'Lars Kern', 'lap_time': '6:38.84', 'power_weight': '700 / 1430'}, {'car': 'McLaren P1 LM', 'driver': 'Kenny Brack', 'lap_time': '6:43.20', 'power_weight': '1000 / 1390'}, {'car': 'AMG GT Black Series', 'driver': 'Maro Engel', 'lap_time': '6:43.62', 'power_weight': '730 / 1637'}, {'car': 'Porsche 911 GT3 RS (992)', 'driver': 'Jörg Bergmeister', 'lap_time': '6:44.85', 'power_weight': '525 / 1480'}, {'car': 'Lamborghini Aventador SVJ', 'driver': 'Marco Mapelli', 'lap_time': '6:44.97', 'power_weight': '770 / 1718'}, {'car': 'Radical SR8 RX', 'driver': 'unknown', 'lap_time': '6:45.50', 'power_weight': '436 / 680'}, {'car': 'Radical SR8LM', 'driver': 'Michael Vergers', 'lap_time': '6:48.00', 'power_weight': '455 / 650'}, {'car': 'Porsche 911 GT3 RS Manthey Racing', 'driver': 'Kevin Estre', 'lap_time': '6:49.66', 'power_weight': '- / -'}, {'car': '911 GT3 Manthey Performance K..', 'driver': 'Kevin Estre', 'lap_time': '6:50.70', 'power_weight': '510 / 1473'}, {'car': 'Huracán Performante', 'driver': 'Marco Mapelli', 'lap_time': '6:52.01', 'power_weight': '640 / 1562'}, {'car': 'AMG GT Black Series', 'driver': 'unknown', 'lap_time': '6:52.54', 'power_weight': '730 / 1637'}, {'car': 'Porsche 911 GT3 RS (992)', 'driver': 'Christian Gebhardt', 'lap_time': '6:54.99', 'power_weight': '525 / 1480'}, {'car': 'Radical SR8', 'driver': 'Michael Vergers', 'lap_time': '6:55.00', 'power_weight': '363 / 650'}, {'car': 'Porsche 911 GT3 (992)', 'driver': 'Lars Kern', 'lap_time': '6:55.34', 'power_weight': '510 / 1456'}, {'car': 'Porsche 918 Spyder', 'driver': 'Marc Lieb', 'lap_time': '6:57.00', 'power_weight': '887 / 1671'}, {'car': 'ModifiedSubaru WRX STI', 'driver': 'unknown', 'lap_time': '6:57.50', 'power_weight': '- / -'}, {'car': 'Porsche 911 GT2 RS (991)', 'driver': 'unknown', 'lap_time': '6:58.00', 'power_weight': '700 / 1515'}, {'car': '718 Cayman GT4 RS Manthey Per..', 'driver': 'Jörg Bergmeister', 'lap_time': '6:58.09', 'power_weight': '500 / 1445'}, {'car': 'Ferrari 296 GTB', 'driver': 'Christian Gebhardt', 'lap_time': '6:58.70', 'power_weight': '830 / 1602'}, {'car': '911 GT3 Manthey Performance K..', 'driver': 'unknown', 'lap_time': '6:59.00', 'power_weight': '510 / 1473'}, {'car': '911 GT3 Manthey Performance K..', 'driver': 'Christian Gebhardt', 'lap_time': '6:59.42', 'power_weight': '510 / 1473'}, {'car': 'Aventador LP750-4 SV', 'driver': 'unknown', 'lap_time': '6:59.73', 'power_weight': '750 / 1735'}, {'car': 'Ferrari 488 Pista', 'driver': 'Christian Gebhardt', 'lap_time': '7:00.03', 'power_weight': '720 / 1476'}, {'car': 'Rimac Nevera', 'driver': 'unknown', 'lap_time': '7:00.93', 'power_weight': '1941 / 2150'}, {'car': 'Dodge Viper ACR (Mk V)', 'driver': 'Lance Arnold', 'lap_time': '7:01.30', 'power_weight': '654 / 1540'}, {'car': 'Chevrolet Corvette ZR1 (C7)', 'driver': 'Jim Mero', 'lap_time': '7:04.00', 'power_weight': '765 / 1651'}, {'car': 'Porsche 718 Cayman GT4 RS', 'driver': 'Jörg Bergmeister', 'lap_time': '7:04.51', 'power_weight': '500 / 1449'}, {'car': 'Mercedes-Benz AMG GT R Pro', 'driver': 'Maro Engel', 'lap_time': '7:04.63', 'power_weight': '585 / 1637'}, {'car': 'Porsche 911 GT3 (992)', 'driver': 'Christian Gebhardt', 'lap_time': '7:04.74', 'power_weight': '510 / 1456'}, {'car': 'Porsche 911 GT3 RS', 'driver': 'unknown', 'lap_time': '7:05.00', 'power_weight': '520 / 1471'}, {'car': 'Nio EP9', 'driver': 'unknown', 'lap_time': '7:05.12', 'power_weight': '1360 / 1735'}, {'car': 'Mercedes-Benz AMG GT R Pro', 'driver': 'unknown', 'lap_time': '7:06.60', 'power_weight': '585 / 1637'}, {'car': 'Mercedes-Benz AMG GT R Pro', 'driver': 'Christian Gebhardt', 'lap_time': '7:07.00', 'power_weight': '585 / 1637'}, {'car': 'Huracán Performante', 'driver': 'Christian Gebhardt', 'lap_time': '7:07.99', 'power_weight': '640 / 1562'}, {'car': 'Huracán Performante', 'driver': 'u ...
# Car Links: [('Mercedes - AMG One', 'https://fastestlaps.com/models/mercedes-amg-one'), ('6:30.70', 'https://fastestlaps.com/tests/l3vctugl6k8u'), ('6:38.84', 'https://fastestlaps.com/tests/2aldjr3pfmcr'), ('McLaren P1 LM', 'https://fastestlaps.com/models/mclaren-p1-lm'), ('6:43.20', 'https://fastestlaps.com/tests/8kjrkihrejo0'), ('AMG GT Black Series', 'https://fastestlaps.com/models/mercedes-benz-amg-gt-r-black-series'), ('6:43.62', 'https://fastestlaps.com/tests/bgg1uhhfd8r1'), ('Porsche 911 GT3 RS (992)', 'https://fastestlaps.com/models/porsche-911-gt3-rs-992'), ('6:44.85', 'https://fastestlaps.com/tests/m4gnh9oev736'), ('Lamborghini Aventador SVJ', 'https://fastestlaps.com/models/lamborghini-aventador-svj'), ('6:44.97', 'https://fastestlaps.com/tests/3bgaa6uo6f7o'), ('Radical SR8 RX', 'https://fastestlaps.com/models/radical-sr8-rx'), ('6:45.50', 'https://fastestlaps.com/tests/587volif7cps'), ('Radical SR8LM', 'https://fastestlaps.com/models/radical-sr8lm'), ('6:48.00', 'https://fastestlaps.com/tests/47jblrfglkc6'), ('6:49.66', 'https://fastestlaps.com/tests/vf2dd2k214mf'), ('911 GT3 Manthey Performance K..', 'https://fastestlaps.com/models/porsche-911-gt3-rs-manthey-performance-kit'), ('6:50.70', 'https://fastestlaps.com/tests/map93m1sk0ga'), ('Huracán Performante', 'https://fastestlaps.com/models/lamborghini-huracn-performante'), ('6:52.01', 'https://fastestlaps.com/tests/k9phi3lels03'), ('AMG GT Black Series', 'https://fastestlaps.com/models/mercedes-benz-amg-gt-r-black-series'), ('6:52.54', 'https://fastestlaps.com/tests/ll22zvnt7vdl'), ('Porsche 911 GT3 RS (992)', 'https://fastestlaps.com/models/porsche-911-gt3-rs-992'), ('6:54.99', 'https://fastestlaps.com/tests/eozju2psecc7'), ('Radical SR8', 'https://fastestlaps.com/models/radical-sr8'), ('6:55.00', 'https://fastestlaps.com/tests/lldce6ltj6gs'), ('Porsche 911 GT3 (992)', 'https://fastestlaps.com/models/porsche-911-gt3-992'), ('6:55.34', 'https://fastestlaps.com/tests/44pl4rhv42cv'), ('Porsche 918 Spyder', 'https://fastestlaps.com/models/porsche-918-spyder'), ('6:57.00', 'https://fastestlaps.com/tests/fu4ikef6f7r4'), ('Subaru WRX STI', 'https://fastestlaps.com/models/subaru-wrx-sti'), ('6:57.50', 'https://fastestlaps.com/tests/jzaac6potvfs'), ('Porsche 911 GT2 RS (991)', 'https://fastestlaps.com/models/porsche-911-gt2-rs-991'), ('6:58.00', 'https://fastestlaps.com/tests/l4il93a52kv5'), ('718 Cayman GT4 RS Manthey Per..', 'https://fastestlaps.com/models/porsche-718-cayman-gt4-rs-manthey-kit'), ('6:58.09', 'https://fastestlaps.com/tests/jckdoaae5c5d'), ('Ferrari 296 GTB', 'https://fastestlaps.com/models/ferrari-296-gtb'), ('6:58.70', 'https://fastestlaps.com/tests/v78ecj66vllj'), ('911 GT3 Manthey Performance K..', 'https://fastestlaps.com/models/porsche-911-gt3-rs-manthey-performance-kit'), ('6:59.00', 'https://fastestlaps.com/tests/odhk8lrsps76'), ('911 GT3 Manthey Performance K..', 'https://fastestlaps.com/models/porsche-911-gt3-rs-manthey-performance-kit'), ('6:59.42', 'https://fastestlaps.com/tests/9h4careil580'), ('Aventador LP750-4 SV', 'https://fastestlaps.com/models/lamborghini-aventador-lp750-4-sv'), ('6:59.73', 'https://fastestlaps.com/tests/87zln3g7fehf'), ('Ferrari 488 Pista', 'https://fastestlaps.com/models/ferrari-488-pista'), ('7:00.03', 'https://fastestlaps.com/tests/j3h864r5j1fm'), ('Rimac Nevera', 'https://fastestlaps.com/models/rimac-c-two'), ('7:00.93', 'https://fastestlaps.com/tests/j1e7g8ko3z2h'), ('Dodge Viper ACR (Mk V)', 'https://fastestlaps.com/models/dodge-viper-acr-mk-v'), ('7:01.30', 'https://fastestlaps.com/tests/288470bs05zc'), ('Chevrolet Corvette ZR1 (C7)', 'https://fastestlaps.com/models/chevrolet-corvette-zr1-n-a'), ('7:04.00', 'https://fastestlaps.com/tests/mllcopblp4ug'), ('Porsche 718 Cayman GT4 RS', 'https://fastestlaps.com/models/porsche-718-gt4-rs'), ('7:04.51', 'https://fastestlaps.com/tests/vl2iboi8ln88'), ('Mercedes-Benz AMG GT R Pro', 'https://fastestlaps.com/models/mercedes-benz-amg-gt-r-pro'), ('7:04.63', 'https://fastest ...
# Car Specs: [{'Top speed': '352 kph (219 mph)', 'Car type': 'Coupe', 'Curb weight': '1695 kg (3737 lbs)', 'Est. max acceleration': '1.02 g (10 m/s²)', '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': '2.9 s', '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': None, 'Car type': None, 'Curb weight': None, 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': None, 'Car type': None, 'Curb weight': None, 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': '345 kph (214 mph)', 'Car type': 'Coupe', 'Curb weight': '1390 kg (3064 lbs)', 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': None, 'Car type': None, 'Curb weight': None, 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': '325 kph (202 mph)', 'Car type': 'Coupe', 'Curb weight': '1623-1657 kg (3578-3653 lbs)', 'Est. max acceleration': '0.93 g (9 m/s²)', '0 - 40 kph': '1.2 s', '0 - 50 kph': '1.4 s', '0 - 60 kph': None, '0 - 80 kph': '2.4 s', '0 - 100 kph': '3.1 s', '0 - 120 kph': None, '0 - 130 kph': '4.4 s', '0 - 140 kph': None}, {'Top speed': None, 'Car type': None, 'Curb weight': None, 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': '296 kph (184 mph)', 'Car type': 'Coupe', 'Curb weight': '1454-1516 kg (3206-3342 lbs)', 'Est. max acceleration': '0.96 g (9 m/s²)', '0 - 40 kph': '1.1 s', '0 - 50 kph': '1.3 s', '0 - 60 kph': '1.4 s', '0 - 80 kph': '2.3 s', '0 - 100 kph': '3.0 s', '0 - 120 kph': '4.9 s', '0 - 130 kph': '4.5 s', '0 - 140 kph': '6.3 s'}, {'Top speed': None, 'Car type': None, 'Curb weight': None, 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': '354 kph (220 mph)', 'Car type': 'Coupe', 'Curb weight': '1525-1781 kg (3362-3926 lbs)', 'Est. max acceleration': '1.06 g (10 m/s²)', '0 - 40 kph': '1.2 s', '0 - 50 kph': '1.3 s', '0 - 60 kph': None, '0 - 80 kph': '2.0 s', '0 - 100 kph': '2.8 s', '0 - 120 kph': '3.8 s', '0 - 130 kph': '4.1 s', '0 - 140 kph': '4.9 s'}, {'Top speed': None, 'Car type': None, 'Curb weight': None, 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': None, 'Car type': 'Coupe', 'Curb weight': '680 kg (1499 lbs)', 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': None, 'Car type': None, 'Curb weight': None, 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': '290 kph (180 mph)', 'Car type': 'Open-wheeler', 'Curb weight': '650 kg (1433 lbs)', 'Est. max acceleration': None, '0 - 40 kph': None, '0 - 50 kph': None, '0 - 60 kph': None, '0 - 80 kph': None, '0 - 100 kph': None, '0 - 120 kph': None, '0 - 130 kph': None, '0 - 140 kph': None}, {'Top speed': None, 'Car type': None, 'Curb ...

# %%
cleaned_data = clean_data(fast_laps, car_specs)

print(cleaned_data)

fast_laps_df, car_specs_df = clean_data(fast_laps, car_specs)

print(f"Fast Laps DataFrame size: {fast_laps_df.shape}")
print(f"Car Specs DataFrame size: {car_specs_df.shape}")

data_saving = save_to_database(fast_laps_df, car_specs_df, railway_key)

print(data_saving)
# Out:
#    Top speed Car type  Curb weight  Est. max acceleration  0 - 40 kph  \
# 0      352.0    Coupe       1695.0                   1.02         NaN
# 1        NaN     None          NaN                    NaN         NaN
# 2        NaN     None          NaN                    NaN         NaN
# 3      345.0    Coupe       1390.0                    NaN         NaN
# 4        NaN     None          NaN                    NaN         NaN
#
#    0 - 50 kph  0 - 60 kph  0 - 80 kph  0 - 100 kph  0 - 120 kph  0 - 130 kph  \
# 0         NaN         NaN         NaN          2.9          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#    0 - 140 kph
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# (                                   car              driver  \
# 0                   Mercedes - AMG One          Maro Engel
# 1    Porsche 911 GT2 RS Manthey Racing           Lars Kern
# 2                        McLaren P1 LM         Kenny Brack
# 3                  AMG GT Black Series          Maro Engel
# 4             Porsche 911 GT3 RS (992)    Jörg Bergmeister
# ..                                 ...                 ...
# 247        Porsche 911 Carrera S (997)             unknown
# 248                     Ferrari 360 CS             unknown
# 249       Alpine A110 S (Mk II 292 PS)  Christian Gebhardt
# 250       SLS AMG Coupe Electric Drive             unknown
# 251              Porsche 911 GT3 (996)        Walter Rohrl
#
#                    lap_time  power_weight
# 0    0 days 00:06:30.700000      0.627139
# 1    0 days 00:06:38.840000      0.489510
# 2    0 days 00:06:43.200000      0.719424
# 3    0 days 00:06:43.620000      0.445938
# 4    0 days 00:06:44.850000      0.354730
# ..                      ...           ...
# 247         0 days 00:07:56      0.240678
# 248         0 days 00:07:56      0.318830
# 249  0 days 00:07:56.100000      0.257269
# 250  0 days 00:07:56.230000      0.358473
# 251  0 days 00:07:56.330000      0.263350
#
# [252 rows x 4 columns],      Top speed Car type  Curb weight  Est. max acceleration  0 - 40 kph  \
# 0        352.0    Coupe       1695.0                   1.02         NaN
# 1          NaN     None          NaN                    NaN         NaN
# 2          NaN     None          NaN                    NaN         NaN
# 3        345.0    Coupe       1390.0                    NaN         NaN
# 4          NaN     None          NaN                    NaN         NaN
# ..         ...      ...          ...                    ...         ...
# 503        NaN     None          NaN                    NaN         NaN
# 504        NaN     None          NaN                    NaN         NaN
# 505        NaN     None          NaN                    NaN         NaN
# 506        NaN     None          NaN                    NaN         NaN
# 507        NaN     None          NaN                    NaN         NaN
#
#      0 - 50 kph  0 - 60 kph  0 - 80 kph  0 - 100 kph  0 - 120 kph  \
# 0           NaN         NaN         NaN          2.9          NaN
# 1           NaN         NaN         NaN          NaN          NaN
# 2           NaN         NaN         NaN          NaN          NaN
# 3           NaN         NaN         NaN          NaN          NaN
# 4           NaN         NaN         NaN          NaN          NaN
# ..          ...         ...         ...          ...          ...
# 503         NaN         NaN         NaN          NaN          NaN
# 504         NaN         NaN         NaN          NaN          NaN
# 505         NaN         NaN         NaN          NaN          NaN
# 506         NaN         NaN         NaN          NaN          NaN
# 507         NaN         NaN         NaN          NaN          NaN
#
#      0 - 130 kph  0 - 140 kph
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 503          NaN          NaN
# 504          NaN          NaN
# 505          NaN          NaN
# 506          NaN          NaN
# 507          NaN          NaN
#
# [508 rows x 12 columns])
#    Top speed Car type  Curb weight  Est. max acceleration  0 - 40 kph  \
# 0      352.0    Coupe       1695.0                   1.02         NaN
# 1        NaN     None          NaN                    NaN         NaN
# 2        NaN     None          NaN                    NaN         NaN
# 3      345.0    Coupe       1390.0                    NaN         NaN
# 4        NaN     None          NaN                    NaN         NaN
#
#    0 - 50 kph  0 - 60 kph  0 - 80 kph  0 - 100 kph  0 - 120 kph  0 - 130 kph  \
# 0         NaN         NaN         NaN          2.9          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#    0 - 140 kph
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 9
#       5 fast_laps_df, car_specs_df = clean_data(fast_laps, car_specs)
#       7 get_prediction_from_chatbot
# ----> 9 car_data_filling = fill_missing_values_with_chatbot(car_specs_df)
#      11 print(f"Fast Laps DataFrame size: {fast_laps_df.shape}")
#      12 print(f"Car Specs DataFrame size: {car_specs_df.shape}")
#
# Cell In[22], line 16, in fill_missing_values_with_chatbot(df)
#      13 predicted_value = get_prediction_from_chatbot(missing_features)
#      15 # Update the DataFrame with the predicted values
# ---> 16 predicted_values = predicted_value.split(",")  # Assuming response comes as comma-separated predictions
#      17 for i, feature in enumerate(missing_features.keys()):
#      18     if feature in df.columns:
#
# AttributeError: 'NoneType' object has no attribute 'split'
